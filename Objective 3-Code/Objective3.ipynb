# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
prd = pd.read_csv('/content/drive/MyDrive/prediction.csv')
prd.describe()
# Out:
#              Year  Temperature Change  GHG emissions: gross  \
# count    33.00000           33.000000             33.000000
# mean   2006.00000            0.474515             76.557121
# std       9.66954            0.482775              5.251707
# min    1990.00000           -0.716000             65.196981
# 25%    1998.00000            0.125000             73.576262
# 50%    2006.00000            0.544000             78.503950
# 75%    2014.00000            0.912000             80.482572
# max    2022.00000            1.319000             82.832552
#
#        Climate related disasters frequency, Number of Disasters: TOTAL  \
# count                                          33.000000
# mean                                            1.151515
# std                                             1.003781
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# ...
