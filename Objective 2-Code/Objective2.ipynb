# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
tr = pd.read_csv('/content/gdrive/MyDrive/Data Analytics - Ass 2/TourismNZ.csv')
tr
# Out:
#     Year  Average Length of Stay  Total Visitor Days  Total Visitor Arrivals  \
# 0   1990                    21.2            20653599                  976010
# 1   1991                    20.0            19288595                  963470
# 2   1992                    19.4            20508284                 1055681
# 3   1993                    19.2            22248380                 1156978
# 4   1994                    19.0            25104664                 1322565
# 5   1995                    19.0            26782546                 1408795
# 6   1996                    19.3            29576829                 1528720
# 7   1997                    19.9            29742588                 1497226
# 8   1998                    19.7            29262762                 1484741
# 9   1999                    20.1            32274185                 1607478
# 10  2000                    20.1            35982318                 1789081
# ...

# %%
tr.sample(5)
# Out:
#     Year  Average Length of Stay  Total Visitor Days  Total Visitor Arrivals  \
# 11  2001                    21.3            40749401                 1909808
# 15  2005                    20.0            47542266                 2382950
# 16  2006                    20.4            49382806                 2421556
# 4   1994                    19.0            25104664                 1322565
# 28  2018                    18.6            73000469                 3915847
#
#     Cumilative CO2 Emission
# 11                 0.112365
# 15                 0.113891
# 16                 0.114094
# 4                  0.109842
# 28                 0.111351

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     31 non-null     int64
#  1   Average Length of Stay   31 non-null     float64
#  2   Total Visitor Days       31 non-null     int64
#  3   Total Visitor Arrivals   31 non-null     int64
#  4   Cumilative CO2 Emission  31 non-null     float64
# dtypes: float64(2), int64(3)
# memory usage: 1.3 KB

# %%
tr.describe()
# Out:
#               Year  Average Length of Stay  Total Visitor Days  \
# count    31.000000               31.000000        3.100000e+01
# mean   2005.000000               19.867742        4.543293e+07
# std       9.092121                0.954424        1.722729e+07
# min    1990.000000               18.500000        1.928860e+07
# 25%    1997.500000               19.150000        2.965971e+07
# 50%    2005.000000               19.900000        4.754227e+07
# 75%    2012.500000               20.150000        5.199761e+07
# max    2020.000000               22.300000        8.105046e+07
#
#        Total Visitor Arrivals  Cumilative CO2 Emission
# count            3.100000e+01                31.000000
# mean             2.302951e+06                 0.111921
# std              9.327257e+05                 0.001698
# min              9.634700e+05                 0.108683
# 25%              1.512973e+06                 0.110808
# 50%              2.382950e+06                 0.111973
# ...

# %%
tr.corr()
# Out:
#                              Year  Average Length of Stay  Total Visitor Days  \
# Year                     1.000000               -0.329579            0.973840
# Average Length of Stay  -0.329579                1.000000           -0.271734
# Total Visitor Days       0.973840               -0.271734            1.000000
# Total Visitor Arrivals   0.971021               -0.378547            0.992975
# Cumilative CO2 Emission  0.542973                0.337444            0.493578
#
#                          Total Visitor Arrivals  Cumilative CO2 Emission
# Year                                   0.971021                 0.542973
# Average Length of Stay                -0.378547                 0.337444
# Total Visitor Days                     0.992975                 0.493578
# Total Visitor Arrivals                 1.000000                 0.414952
# Cumilative CO2 Emission                0.414952                 1.000000

# %%
vs = pd.read_csv('/content/gdrive/MyDrive/Data Analytics - Ass 2/visitor.csv')

# %%
vs.corr()
# Out:
#                         Total Visitor Days  Total Visitor Arrivals  \
# Total Visitor Days                1.000000                0.992975
# Total Visitor Arrivals            0.992975                1.000000
# Annual CO₂ emissions              0.796396                0.741854
#
#                         Annual CO₂ emissions
# Total Visitor Days                  0.796396
# Total Visitor Arrivals              0.741854
# Annual CO₂ emissions                1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

correlation_matrix = vs.corr()

plt.figure(figsize=(8, 8))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, fmt=".1f", linewidths=.5)
plt.title("Correlation Heatmap for Annual CO2 emissions and total number of tourist visitors")
plt.show()
